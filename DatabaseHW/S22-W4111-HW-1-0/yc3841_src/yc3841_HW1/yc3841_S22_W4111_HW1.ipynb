# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
#
# }
#
# </style>
#
# <b><center>
#     <span style="font-size: 24pt; line-height: 1.2;">COMS W4111: Introduction to Databases</span><br>
#     <span style="font-size: 24pt; line-height: 1.2;">Section 002/V02, Spring, 2022</span><br>
# </center></b>
# <br><br>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2;">HW 1 Notebook</span>
# </center></i>

# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook has three top level sections:
# 1. _Setup_ tests the environment setup, and should work assuming you completed HW0.
# 1. _Common Tasks_ are the HW1 tasks for both the programming and non-programming track. All students complete this section.
# 2. _Non-Programing Track_ contains the tasks that students in the non-programming track must complete.
# 3. _Programming Track_ contains the tasks that students in the programming track must complete.
#
#
# Submission format:
#
# - All students (both tracks) submit a completed version of this notebook. Students need to complete the setup section, the common section, and the section specific to their track. The submission format is a PDF generated from the notebook. Students can generate the PDF by:
#     - Choosing ```File->Print Preview``` in the notebook's menu bar. This will open a new browser tab.
#     - In the new browser tab, select ```File->Print``` and choose to save as PDF.
#     - **Make sure that everything renders properly in the generated PDF.** Troubleshoot/reach out if you have issues. Images/outputs that render incorrectly will not be graded.
#
#
# - All students submit a zip file containing their cloned HW0/1 project, which they got by cloning the [GitHub repository.](https://github.com/donald-f-ferguson/S22-W4111-HW-1-0) Students can:
#     - Open a command/terminal window in the root directory where they cloned the project.
#     - Enter ```git pull``` to retrieve any updates to the project, including required data files.
#
#
# - Students can edit the notebook using Anaconda Navigator to open Jupyter Notebook.
#
#
#
# - Students on the programming track also create and modify Python files in the sub-folder ```<UNI>_web_src```. Remember, you should be using a folder with your UNI. In my case, the folder would be ```dff9_web_src.```
#
#
#
# - The zip file you submit should contain __only__ the following sub-folders/files:
#     - ```<UNI>_src.``` (All students) This folder must container your version of this notebook.
#     - ```<UNI>_web_src.``` (Only programming track)
#     - To be clear: the zipped directory for non-programming track submissions should contain **one** file. The corresponding ``zip`` for the programming track should contain **two** files.
#
#
# - Make sure to submit your notebook in the PDF format separately from the zip file, based on your track as well. That is, you need to make __two__ submissions in total like below:
#     - Submit your notebook file in PDF format to ```Homework 1: Non-programming or Programming``` __(Make sure that you assigned pages properly).__
#     - Submit your zip file to ```Homework 1: Zip File Submission```

# %% [markdown]
# # Setup
#
# __Note:__ You will have to put the correct user ID and password in the connection strings below, e.g. replace ```dbuser``` and ```dbuserdbuser.```

# %%
import sqlalchemy
sqlalchemy.__version__
# Out:
# '1.4.27'

# %% [markdown]
# ## iPython-SQL

# %%
# %load_ext sql

# %% [markdown]
# ```https://www.columbia.edu/```

# %%
# %sql mysql+pymysql://root:Iriswonder5216@localhost
# Out:
# 'Connected: root@None'

# %%
# %sql select * from db_book.student where name like "z%" or name like "sh%"
# Out:
#  * mysql+pymysql://root:***@localhost
# (pymysql.err.OperationalError) (1049, "Unknown database 'db_book'")
# [SQL: select * from db_book.student where name like "z%%" or name like "sh%%"]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ## PyMySQL

# %%
import pymysql

# %%
conn = pymysql.connect(host="localhost", user="root", password="Iriswonder5216")

# %%
conn

# %%
sql = """
    select * from db_book.student where
        name like %s or name like %s
"""

# %%
pattern_1 = "z%"
pattern_2 = "sh%"

# %%
cur = conn.cursor()
res = cur.execute(
    sql, args=(pattern_1, pattern_2)
)
res
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /var/folders/pb/qqpfp2vj4k5d6cfcjq7_wtd00000gn/T/ipykernel_77383/1896349519.py in <module>
#       1 cur = conn.cursor()
# ----> 2 res = cur.execute(
#       3     sql, args=(pattern_1, pattern_2)
#       4 )
#       5 res
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (1049, "Unknown database 'db_book'")

# %%
res = cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /var/folders/pb/qqpfp2vj4k5d6cfcjq7_wtd00000gn/T/ipykernel_77383/3441107905.py in <module>
# ----> 1 res = cur.fetchall()
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py in fetchall(self)
#     281     def fetchall(self):
#     282         """Fetch all the rows"""
# --> 283         self._check_executed()
#     284         if self._rows is None:
#     285             return ()
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py in _check_executed(self)
#      68     def _check_executed(self):
#      69         if not self._executed:
# ---> 70             raise err.ProgrammingError("execute() first")
#      71
#      72     def _conv_row(self, row):
#
# ProgrammingError: execute() first

# %%
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pb/qqpfp2vj4k5d6cfcjq7_wtd00000gn/T/ipykernel_77383/1158820258.py in <module>
# ----> 1 res
#
# NameError: name 'res' is not defined

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
#
#  Replace the path below with the path of your project directory.
#  Use // instead of / if you're on Windows.
#
project_root = "/Users/yanxichen/Desktop/DatabaseHW/S22-W4111-HW-1-0"

# %%
people_df = pd.read_csv(project_root + "/data/People.csv")

# %%
people_df
# Out:
#         playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0      aardsda01     1981.0        12.0      27.0          USA         CO
# 1      aaronha01     1934.0         2.0       5.0          USA         AL
# 2      aaronto01     1939.0         8.0       5.0          USA         AL
# 3       aasedo01     1954.0         9.0       8.0          USA         CA
# 4       abadan01     1972.0         8.0      25.0          USA         FL
# ...          ...        ...         ...       ...          ...        ...
# 20353   zupofr01     1939.0         8.0      29.0          USA         CA
# 20354  zuvelpa01     1958.0        10.0      31.0          USA         CA
# 20355  zuverge01     1924.0         8.0      20.0          USA         MI
# 20356  zwilldu01     1888.0        11.0       2.0          USA         MO
# 20357   zychto01     1990.0         8.0       7.0          USA         IL
#
#            birthCity  deathYear  deathMonth  deathDay  ...  nameLast  \
# 0             Denver        NaN         NaN       NaN  ...   Aardsma
# 1             Mobile     2021.0         1.0      22.0  ...     Aaron
# 2             Mobile     1984.0         8.0      16.0  ...     Aaron
# 3             Orange        NaN         NaN       NaN  ...      Aase
# 4         Palm Beach        NaN         NaN       NaN  ...      Abad
# ...              ...        ...         ...       ...  ...       ...
# 20353  San Francisco     2005.0         3.0      25.0  ...      Zupo
# 20354      San Mateo        NaN         NaN       NaN  ...   Zuvella
# 20355        Holland     2014.0         9.0       8.0  ...  Zuverink
# 20356      St. Louis     1978.0         3.0      27.0  ...  Zwilling
# 20357          Monee        NaN         NaN       NaN  ...      Zych
#
#              nameGiven weight height bats throws       debut   finalGame  \
# 0          David Allan  215.0   75.0    R      R  2004-04-06  2015-08-23
# 1          Henry Louis  180.0   72.0    R      R  1954-04-13  1976-10-03
# 2           Tommie Lee  190.0   75.0    R      R  1962-04-10  1971-09-26
# 3       Donald William  190.0   75.0    R      R  1977-07-26  1990-10-03
# 4        Fausto Andres  184.0   73.0    L      L  2001-09-10  2006-04-13
# ...                ...    ...    ...  ...    ...         ...         ...
# 20353     Frank Joseph  182.0   71.0    L      R  1957-07-01  1961-05-09
# 20354             Paul  173.0   72.0    R      R  1982-09-04  1991-05-02
# 20355           George  195.0   76.0    R      R  1951-04-21  1959-06-15
# 20356  Edward Harrison  160.0   66.0    L      L  1910-08-14  1916-07-12
# 20357    Anthony Aaron  190.0   75.0    R      R  2015-09-04  2017-08-19
#
#         retroID    bbrefID
# 0      aardd001  aardsda01
# 1      aaroh101  aaronha01
# 2      aarot101  aaronto01
# 3      aased001   aasedo01
# 4      abada001   abadan01
# ...         ...        ...
# 20353  zupof101   zupofr01
# 20354  zuvep001  zuvelpa01
# 20355  zuveg101  zuverge01
# 20356  zwild101  zwilldu01
# 20357  zycht001   zychto01
#
# [20358 rows x 24 columns]

# %%
people_df.loc[
    (people_df['nameLast'] == "Williams") & (people_df['birthCity'] == 'San Diego'),
    ["playerID", "nameLast", "nameFirst", "birthYear", 'birthCity', 'bats', 'throws']
]
# Out:
#         playerID  nameLast nameFirst  birthYear  birthCity bats throws
# 19773  willite01  Williams       Ted     1918.0  San Diego    L      R
# 19776  willitr01  Williams    Trevor     1992.0  San Diego    R      R

# %% [markdown]
# ## SQLAlchemy

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:Iriswonder@5216@localhost")

# %%
sql = """
    select * from db_book.student where
        name like %s or name like %s
"""
pattern_1 = "z%"
pattern_2 = "sh%"

# %%
another_df = pd.read_sql(sql, params=(pattern_1, pattern_2), con=engine)
another_df
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# /opt/anaconda3/lib/python3.9/socket.py in create_connection(address, timeout, source_address)
#     822     err = None
# --> 823     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     824         af, socktype, proto, canonname, sa = res
#
# /opt/anaconda3/lib/python3.9/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3242         try:
# -> 3243             return fn()
#    3244         except dialect.dbapi.Error as e:
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352         else:
# --> 353             self.connect()
#     354
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in connect(self, sock)
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#
# OperationalError: (2003, "Can't connect to MySQL server on '5216@localhost' ([Errno 8] nodename nor servname provided, or not known)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /var/folders/pb/qqpfp2vj4k5d6cfcjq7_wtd00000gn/T/ipykernel_77383/2935734635.py in <module>
# ----> 1 another_df = pd.read_sql(sql, params=(pattern_1, pattern_2), con=engine)
#       2 another_df
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     590         )
#     591     else:
# --> 592         return pandas_sql.read_query(
#     593             sql,
#     594             index_col=index_col,
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1555         args = _convert_params(sql, params)
#    1556
# -> 1557         result = self.execute(*args)
#    1558         columns = result.keys()
#    1559
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1400     def execute(self, *args, **kwargs):
#    1401         """Simple passthrough to SQLAlchemy connectable"""
# -> 1402         return self.connectable.execution_options().execute(*args, **kwargs)
#    1403
#    1404     def read_table(
#
# <string> in execute(self, statement, *multiparams, **params)
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     399         if not skip_warning:
#     400             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401         return fn(*args, **kwargs)
#     402
#     403     doc = func.__doc__ is not None and func.__doc__ or ""
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    3136
#    3137         """
# -> 3138         connection = self.connect(close_with_result=True)
#    3139         return connection.execute(statement, *multiparams, **params)
#    3140
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in connect(self, close_with_result)
#    3195         """
#    3196
# -> 3197         return self._connection_cls(self, close_with_result=close_with_result)
#    3198
#    3199     @util.deprecated(
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    3274
#    3275         """
# -> 3276         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3277
#    3278
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3244         except dialect.dbapi.Error as e:
#    3245             if connection is None:
# -> 3246                 Connection._handle_dbapi_exception_noconnection(
#    3247                     e, dialect, self
#    3248                 )
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2098             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2099         elif should_wrap:
# -> 2100             util.raise_(
#    2101                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2102             )
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3241         dialect = self.dialect
#    3242         try:
# -> 3243             return fn()
#    3244         except dialect.dbapi.Error as e:
#    3245             if connection is None:
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in connect(self)
#     308
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#     312     def _return_conn(self, record):
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     866     def _checkout(cls, pool, threadconns=None, fairy=None):
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#     870             fairy._pool = pool
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     474     @classmethod
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#     478             dbapi_connection = rec.get_connection()
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     254         """Called by subclasses to create a new ConnectionRecord."""
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#     258     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     369         self.__pool = pool
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#     373
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     664         except Exception as e:
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#     668             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     659         try:
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#     663             self.fresh = True
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     588                     if connection is not None:
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#     592         creator = pop_kwarg("creator", connect)
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/pymysql/connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '5216@localhost' ([Errno 8] nodename nor servname provided, or not known)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# # Common Tasks

# %% [markdown]
# ## Schema and Data Modeling

# %% [markdown]
# - There are three entity types:
#     1. Employee with attributes:
#         - employee_no
#         - last_name
#         - first_name
#     2. Department with attributes
#         - department_id
#         - department_name
#     3. Applicant with attributes:
#         - email
#         - last_name
#         - first_name

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Relational Schema
#
# - Using the notation from the textbook slides and lecture notes, define the relation definitions for each of the entity types. That is, the schema definition for the relations. You will need to choose a primary key.
#
#
# - The snippet below shows how to use under-bar.

# %% [markdown]
# \begin{equation}
# This\ is\ a\ sentence\ with\ someting\_in\_parentheses(
#     \underline{something}, another\_thing)\  and\ something\ with\ underbar.
# \end{equation}

# %% [markdown]
# You can double click on the cell above to see the source, which is
# ```
# \begin{equation}
# This\ is\ a\ sentence\ with\ someting\_in\_parentheses(
#     \underline{something}, another\_thing)\  and\ something\ with\ underbar.
# \end{equation}
# ```

# %% [markdown]
# Put your relation definitions below between the horizontal lines.
#
# <hr style="height: 1px";>
#
# \begin{equation}
# employee(\underline{employee\_nummber}, last\_name, first\_name)
# \end{equation}
# \begin{equation}
# department(\underline{department\_id}, department\_name)
# \end{equation}
# \begin{equation}
# applicant(\underline{email}, last\_name, first\_name)
# \end{equation}
#
# <hr style="height: 1px";>

# %% [markdown]
# ### ER Modeling
#
# - Continuing the example above:
#     - An _employee_ is a _member\_of_ exactly one _department_.
#     - An _applicant_ has exactly one _employee_ who is _sponsor\_of_ of the applicant.
#     - An _applicant_ may have specified a _department_ that is the _applicant's_ _preferred\_dept._
#
#
# - Use [Lucidchart](https://www.lucidchart.com) to draw the logical diagram.
#
#
# - __Note:__ You may have to add columns/attributes to some tables to implement the relationships.
#
#
# - To submit the diagram, take a screen capture and modify the cell below to load your diagram from the file system. The following is an example for how to include the screenshot.

# %%
er_model_file_name = 'ERhw1.png'

print("\n")
from IPython.display import Image
Image(filename=er_model_file_name)

# %% [markdown]
# ## Relational Algebra
#
# ### Instructions
#
# - You will use the [RelaX](https://dbis-uibk.github.io/relax/calc/gist/4f7866c17624ca9dfa85ed2482078be8/relax-silberschatz-english.txt/0) online relational algebra calculator.
#
#
# - You must use the dataset ```Silberschatz - UniversityDB.``` I demonstrated how to select a dataset during a lecture.
#
#
# - For submitting your answer, you must:
#     - Cut and paste your relational expression in text.
#     - Take a screenshot and include the image.
#
#
# - The following is an example question and answer.

# %% [markdown]
# ### Example
#
# __Question:__ Produce a table of the form ```(course_id, title, prereq_id, preqreq_title)``` that lists courses and their prereqs.
#
#
# <hr style="height:1px;">
#
# ```
# π course_id, title, prereq_id, prereq_title
#     (
#         (π course_id, title, prereq_id (course ⨝ prereq))
#         ⨝ prereq_id=x
#         (π x←course_id, prereq_title←title (course))
# ```

# %%
er_model_file_name = 'Screen Shot 2022-02-06 at 3.04.39 PM.png'

print("\n")
from IPython.display import Image
Image(filename=er_model_file_name)

# %% [markdown]
# <hr style="height: 1px;">

# %% [markdown]
# ### Relational Algebra Q1

# %% [markdown]
# - Use ```student, advisor``` and ```instructor``` for this question.
#
#
# - Produce a table of the form ```(student.ID, student.name, instructor.ID, instructor.name)``` that shows students and their advisors.

# %% [markdown]
# <hr style="height: 1px;">

# %% [markdown]
# ```
# π student.ID,student.name,instructor.ID,instructor.name
#  (student ⨝ s_id=student.ID (instructor ⨝ instructor.ID=i_id advisor))
# ```

# %%
er_model_file_name = 'RAQ1.png'

print("\n")
from IPython.display import Image
Image(filename=er_model_file_name)

# %% [markdown]
# <hr style="height: 1px;">

# %% [markdown]
# ### Relational Algebra Q2

# %% [markdown]
# - Use ```student``` and ```takes``` for this question.
#
#
# - Produce a table of the form ```(student.ID, student.name, student.tot_cred, student_dept_name)``` for students that have not taken any course/section.

# %% [markdown]
# <hr style="height: 1px;">

# %% [markdown]
# ```
# (π student.ID, student.name, student.tot_cred, student.dept_name (student)) - (π student.ID, student.name, student.tot_cred, student.dept_name (student⨝takes))
# ```

# %%
er_model_file_name = 'RAQ2.png'

print("\n")
from IPython.display import Image
Image(filename=er_model_file_name)

# %% [markdown]
# <hr style="height: 1px;">

# %% [markdown]
# ## SQL

# %% [markdown]
# ### Instructions
#
# - The questions in this section ask you to write and execute SQL statements.
#
#
# - Your answer should be a code cell with ```%sql``` and your query.
#
#
# - You must execute the query.

# %% [markdown]
# ### Example
#
# - This is the SQL version of the query from the relational algebra section above.

# %% [markdown]
# <hr style="height: 1px;">

# %%
# %%sql
# use db_book;
#
# select a.course_id as course_id,
#        a.title as title,
#        prereq_id,
#        b.title as prereq_tiles
# from
#               (select course_id, title, prereq_id from course join prereq using(course_id)) as a
# join
#     course as b on a.prereq_id=b.course_id
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 7 rows affected.
# [('BIO-301', 'Genetics', 'BIO-101', 'Intro. to Biology'),
#  ('BIO-399', 'Computational Biology', 'BIO-101', 'Intro. to Biology'),
#  ('CS-190', 'Game Design', 'CS-101', 'Intro. to Computer Science'),
#  ('CS-315', 'Robotics', 'CS-101', 'Intro. to Computer Science'),
#  ('CS-319', 'Image Processing', 'CS-101', 'Intro. to Computer Science'),
#  ('CS-347', 'Database System Concepts', 'CS-101', 'Intro. to Computer Science'),
#  ('EE-181', 'Intro. to Digital Systems', 'PHY-101', 'Physical Principles')]

# %% [markdown]
# <hr style="height: 1px;">

# %% [markdown]
# ### SQL Question 1
#
# - Translate your answer from Relational Algebra Q1 into SQL.
#
#
# - Do not worry about correctly naming the columns.

# %% [markdown]
# <hr style="height: 1px">

# %%
# %%sql
# use db_book;
#
# select student.ID,
#        student.name,
#        instructor.ID,
#        instructor.name
# from
#               (student join (instructor join advisor on instructor.ID=i_id)on s_id=student.ID)
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 9 rows affected.
# [('12345', 'Shankar', '10101', 'Srinivasan'),
#  ('44553', 'Peltier', '22222', 'Einstein'),
#  ('45678', 'Levy', '22222', 'Einstein'),
#  ('00128', 'Zhang', '45565', 'Katz'),
#  ('76543', 'Brown', '45565', 'Katz'),
#  ('23121', 'Chavez', '76543', 'Singh'),
#  ('98988', 'Tanaka', '76766', 'Crick'),
#  ('76653', 'Aoi', '98345', 'Kim'),
#  ('98765', 'Bourikas', '98345', 'Kim')]

# %% [markdown]
# <hr style="height: 1px">

# %% [markdown]
# ### SQL Question 2
#
# - You guessed it.
#
#
# - Translate your answer from Relational Algebra Q2 into SQL.
#
#
# - Do not worry about correctly naming the columns.
#
# S
#
# Y is students that have not taken a section
#     Y = S JOIN takes

# %% [markdown]
# <hr style="height: 1px">

# %%
# %%sql
# use db_book;
#
# select student.ID,
#        student.name,
#        student.tot_cred,
#        student.dept_name
# from
#        student where
# not student.ID in (select student.ID from student join takes using(ID))
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 1 rows affected.
# [('70557', 'Snow', Decimal('0'), 'Physics')]

# %% [markdown]
# <hr style="height: 1px">

# %% [markdown]
# ### SQL Question 3
#
#
# - The following query makes a copy of the ```department``` table.

# %%
# %%sql
#
# drop table if exists hw1_department;
# create table hw1_department as select * from department;
#
# #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# (pymysql.err.ProgrammingError) (1146, "Table 'aa_s22_w4111_hw1.department' doesn't exist")
# [SQL: create table hw1_department as select * from department;]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %% [markdown]
# - The next query shows the content.

# %%
# %sql select * from db_book.hw1_department
# Out:
#  * mysql+pymysql://root:***@localhost
# 7 rows affected.
# [('Biology', 'Watson', Decimal('90000.00'), None),
#  ('Comp. Sci.', 'Taylor', Decimal('100000.00'), None),
#  ('Elec. Eng.', 'Taylor', Decimal('85000.00'), None),
#  ('Finance', 'Painter', Decimal('120000.00'), None),
#  ('History', 'Painter', Decimal('50000.00'), None),
#  ('Music', 'Packard', Decimal('80000.00'), None),
#  ('Physics', 'Watson', Decimal('70000.00'), None)]

# %% [markdown]
# - You have two tasks for this question.
#     1. Create a new table ```db_book.hw1_schools``` that has columns ```school_id``` and ```school_name.```
#     2. Modify table ```db_book.hw1_department``` to contain a columns ```school_id.```
#
#
# - __Notes:__
#     - You do not have to worry about foreign keys.
#     - You do not need to populate any data or link ```school_id``` to the ```hw1_schools.```
#     - You can use DataGrip or another tool to produce the SQL DDL, but you must show successful execution on the code cells below.

# %% [markdown]
# <hr style="height: 1px">

# %%
# %%sql
# use db_book;
#
# drop table if exists hw1_schools;
#
# create table hw1_schools
# (
# 	school_id varchar(4) null,
# 	school_name varchar(64) null
# );
#
# #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'ON' at line 2")
# [SQL: #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
#
# use db_book;
#
# alter table hw1_department
# 	add school_id varchar(4) null;
#
# #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# (pymysql.err.OperationalError) (1060, "Duplicate column name 'school_id'")
# [SQL: alter table hw1_department
# 	add school_id varchar(4) null;]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# %sql select * from db_book.hw1_department
# Out:
#  * mysql+pymysql://root:***@localhost
# 7 rows affected.
# [('Biology', 'Watson', Decimal('90000.00'), None),
#  ('Comp. Sci.', 'Taylor', Decimal('100000.00'), None),
#  ('Elec. Eng.', 'Taylor', Decimal('85000.00'), None),
#  ('Finance', 'Painter', Decimal('120000.00'), None),
#  ('History', 'Painter', Decimal('50000.00'), None),
#  ('Music', 'Packard', Decimal('80000.00'), None),
#  ('Physics', 'Watson', Decimal('70000.00'), None)]

# %% [markdown]
# <hr style="height: 1px">

# %% [markdown]
# # Non-Programming Track

# %% [markdown]
# ## Tasks

# %% [markdown]
# - There is a subdirectory in the project ```data/GoT``` that contains three CSV files:
#     - ```characters.csv```
#     - ```episodes.csv```
#     - ```character_relationships.csv```
#
#
# - Your first task is to create tables to hold the data.
#     - This means you must create three tables. Use a new schema and create the three tables:
#         - ```S22_W4111_HW1.characters```
#         - ```S22_W4111_HW1.episodes```
#         - ```S22_W4111_HW1.character_relationships.```
#     - The table must have a column for each of the columns in the CSV.
#     - You can use DataGrip or another tool to produce the create table statements, but you must execute the DDL statements in the code cells.
#
#
# - Your second task is to load the data from the CSV files into the newly created tables. Do do this, you use a ```LOAD``` statement.
#
#
# - Finally, you should examine the data and change column types to better reflect the actual values in the columns.
#
#
# - To make the instruction more clear, I do an example of the tasks for another table. This is ```got_imdb_names.csv.``` You will do similar steps for the files above.

# %% [markdown]
# ## Example

# %% [markdown]
# - Manual examining the CSV file shows that the data has the following attributes.
#     - ```nconst```
#     - ```primaryName```
#     - ```birthYear```
#     - ```deathYear```
#     - ```primaryProfession```
#     - ```knownForTitles```
#
#
# - So, my first step is to create a table to hold the information.
#
#
# - __Note:__ I have dozens of schema. So, I am prefixing this one with ```aaaa_``` to make it easy for me to find. You can drop this prefix.
#
#
# - The following are the statements for creating the schema and table.

# %% [markdown]
# ```nconst	primaryName	birthYear	deathYear	primaryProfession	knownForTitles```

# %%
# Create the schema if it does not exist.
# %sql create schema if not exists aaaa_S22_W4111_HW1;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-267-e4b39979fb38> in <module>
#       1 # Create the schema if it does not exist.
# ----> 2 get_ipython().run_line_magic('sql', 'create schema if not exists aaaa_S22_W4111_HW1;')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# Drop the table if it exists.
# %sql drop table if exists aaaa_S22_W4111_HW1.got_imdb_actors;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-263-1c998c6140ef> in <module>
#       1 # Drop the table if it exists.
# ----> 2 get_ipython().run_line_magic('sql', 'drop table if exists aaaa_S22_W4111_HW1.got_imdb_actors;')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %% [markdown]
# - Now create the table.

# %%
# %%sql
# create table if not exists aaaa_S22_W4111_HW1.got_imdb_actors
# (
# 	nconst text null,
# 	primaryName text null,
# 	birthYear text null,
# 	deathYear text null,
# 	primaryProfession text null,
# 	knownForTitles text null
# );
#
# #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'ON' at line 2")
# [SQL: #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %% [markdown]
# - This is where it gets real and you do some wizard stuff.

# %%
# This command allows loading CSV files from the local disk.
# This is set of OFF by default.
# You should only have to run this once, that is if you execute the example, you do not need to do again.
#
# %sql SET GLOBAL local_infile = 'ON';
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-209-3dae89daab24> in <module>
#       3 # You should only have to run this once, that is if you execute the example, you do not need to do again.
#       4 #
# ----> 5 get_ipython().run_line_magic('sql', "SET GLOBAL local_infile = 'ON';")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# This is creating a connection to the database.
# You need to replace the user and passsword with your values for your installation of MySQL.
# Do not ask about the local_infile. That is Voldemort stuff.
#
con = pymysql.connect(host="localhost",
                        user="root",
                        password="Iriswonder@5216",
                        autocommit=True,
                        local_infile=1)

# %%
# This statement performs the load.
# You will need to change the TABLE name and the INFILE to the correct values.
#
sql = """
LOAD DATA LOCAL INFILE
'/Users/yanxichen/Desktop/DatabaseHW/S22-W4111-HW-1-0/data/GoT/got_imdb_actors.csv'
INTO TABLE aaaa_S22_W4111_HW1.got_imdb_actors
    FIELDS TERMINATED BY ','
    ENCLOSED BY '"'
    LINES TERMINATED BY '\n'
    IGNORE 1 LINES;
"""

# %%
# Create a cursor. Again. Voldemort stuff, or maybe Sauron stuff.
#
cur = con.cursor()

# %%
# Run the sql
cur.execute(sql)
# Out:
# 351

# %%
# Close the cursor. Sort of like the opposite of alohomora
cur.close()

# %%
# Now test that your loading worked.
# %sql select * from aaaa_S22_W4111_HW1.got_imdb_actors limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost
# 10 rows affected.
# [('nm0389698', 'B.J. Hogg', '1955', '2020', 'actor,music_department', 'tt0944947,tt0986233,tt1240982,tt0970411'),
#  ('nm0269923', 'Michael Feast', '1946', '', 'actor,composer', 'tt0472160,tt0162661,tt0362192,tt0120879'),
#  ('nm0727778', 'David Rintoul', '1948', '', 'actor', 'tt1139328,tt1655420,tt4786824,tt1007029'),
#  ('nm6729880', 'Chuku Modu', '1990', '', 'actor,writer,producer', 'tt0944947,tt2674426,tt4154664,tt6470478'),
#  ('nm0853583', 'Owen Teale', '1961', '', 'actor', 'tt0462396,tt0485301,tt0102797,tt0944947'),
#  ('nm0203801', 'Karl Davies', '1982', '', 'actor,producer', 'tt7366338,tt3428912,tt2261331,tt0944947'),
#  ('nm8257864', 'Megan Parkinson', '', '', 'actress', 'tt6636246,tt4276618,tt0944947,tt5761478'),
#  ('nm0571654', 'Fintan McKeown', '', '', 'actor', 'tt0111904,tt0944947,tt0112178,tt0166396'),
#  ('nm1528121', 'Philip McGinley', '1981', '', 'actor', 'tt4015216,tt0944947,tt1446714,tt0053494'),
#  ('nm0000980', 'Jim Broadbent', '1949', '', 'actor,writer,soundtrack', 'tt0203009,tt1007029,tt0151568,tt1431181')]

# %%
# %sql describe aaaa_S22_W4111_HW1.got_imdb_actors;
# Out:
#  * mysql+pymysql://root:***@localhost
# 6 rows affected.
# [('nconst', 'text', 'YES', '', None, ''),
#  ('primaryName', 'text', 'YES', '', None, ''),
#  ('birthYear', 'text', 'YES', '', None, ''),
#  ('deathYear', 'text', 'YES', '', None, ''),
#  ('primaryProfession', 'text', 'YES', '', None, ''),
#  ('knownForTitles', 'text', 'YES', '', None, '')]

# %% [markdown]
# - The final part of the task for each of the tables will be making some corrections.
#
#
# - We would only ask you to do two or three corrections per table.
#
#
# - Mine for this example would be in the following.

# %%
# %%sql
#
# use aaaa_S22_W4111_HW1;
#
# alter table got_imdb_actors modify nconst varchar(12) null;
#
# alter table got_imdb_actors modify primaryName varchar(256) null;
#
# alter table got_imdb_actors modify birthYear char(4) null;
#
# alter table got_imdb_actors modify deathYear char(4) null;
#
# #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 351 rows affected.
# 351 rows affected.
# 351 rows affected.
# 351 rows affected.
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'ON' at line 2")
# [SQL: #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %sql describe aaaa_S22_W4111_HW1.got_imdb_actors;
# Out:
#  * mysql+pymysql://root:***@localhost
# 6 rows affected.
# [('nconst', 'varchar(12)', 'YES', '', None, ''),
#  ('primaryName', 'varchar(256)', 'YES', '', None, ''),
#  ('birthYear', 'char(4)', 'YES', '', None, ''),
#  ('deathYear', 'char(4)', 'YES', '', None, ''),
#  ('primaryProfession', 'text', 'YES', '', None, ''),
#  ('knownForTitles', 'text', 'YES', '', None, '')]

# %% [markdown]
# ## Characters
#
# - Perform the tasks for characters.

# %%
# Create the schema if it does not exist.
# %sql create schema if not exists aa_S22_W4111_HW1;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-219-6cbb95b49b85> in <module>
#       1 # Create the schema if it does not exist.
# ----> 2 get_ipython().run_line_magic('sql', 'create schema if not exists aa_S22_W4111_HW1;')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# Drop the table if it exists.
# %sql drop table if exists aa_S22_W4111_HW1.characters;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-221-49cc365c36ec> in <module>
#       1 # Drop the table if it exists.
# ----> 2 get_ipython().run_line_magic('sql', 'drop table if exists aa_S22_W4111_HW1.characters;')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# create table if not exists aa_S22_W4111_HW1.characters
# (
# 	characterName text null,
# 	characterLink text null,
# 	actorName text null,
# 	actorLink text null,
# 	id text null,
# 	royal text null,
#     characterImageThumb text null,
#     characterImageFull text null,
#     nickname text null,
#     kingsguard text null
# );
#
# #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'ON' at line 2")
# [SQL: #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# This command allows loading CSV files from the local disk.
# This is set of OFF by default.
# You should only have to run this once, that is if you execute the example, you do not need to do again.
#
# %sql SET GLOBAL local_infile = 'ON';
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-223-3dae89daab24> in <module>
#       3 # You should only have to run this once, that is if you execute the example, you do not need to do again.
#       4 #
# ----> 5 get_ipython().run_line_magic('sql', "SET GLOBAL local_infile = 'ON';")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# This is creating a connection to the database.
# You need to replace the user and passsword with your values for your installation of MySQL.
# Do not ask about the local_infile. That is Voldemort stuff.
#
con = pymysql.connect(host="localhost",
                        user="root",
                        password="Iriswonder@5216",
                        autocommit=True,
                        local_infile=1)

# %%
# This statement performs the load.
# You will need to change the TABLE name and the INFILE to the correct values.
#
sql = """
LOAD DATA LOCAL INFILE
'/Users/yanxichen/Desktop/DatabaseHW/S22-W4111-HW-1-0/data/GoT/characters.csv'
INTO TABLE aa_S22_W4111_HW1.characters
    FIELDS TERMINATED BY ','
    ENCLOSED BY '"'
    LINES TERMINATED BY '\n'
    IGNORE 1 LINES;
"""

# %%
# Create a cursor. Again. Voldemort stuff, or maybe Sauron stuff.
#
cur = con.cursor()

# %%
# Run the sql
cur.execute(sql)
# Out:
# 389

# %%
# Close the cursor. Sort of like the opposite of alohomora
cur.close()

# %%
# Now test that your loading worked.
# %sql select * from aa_S22_W4111_HW1.characters limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost
# 10 rows affected.
# [('Addam Marbrand', '/character/ch0305333/', 'B.J. Hogg', '/name/nm0389698/', '6191091c06029e3acded09e1', '', '', '', '', ''),
#  ('Aegon Targaryen', '', '', '', '6191091c06029e3acded09e2', '1', '', '', '', ''),
#  ('Aeron Greyjoy', '/character/ch0540081/', 'Michael Feast', '/name/nm0269923/', '6191091c06029e3acded09e3', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzI5MDg0ZDAtN2Y2ZC00MzU1LTgyYjQtNTBjYjEzODczZDVhXkEyXkFqcGdeQXVyNTg0Nzg4NTE@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzI5MDg0ZDAtN2Y2ZC00MzU1LTgyYjQtNTBjYjEzODczZDVhXkEyXkFqcGdeQXVyNTg0Nzg4NTE@._V1_.jpg', 'Damphair', ''),
#  ('Aerys II Targaryen', '/character/ch0541362/', 'David Rintoul', '/name/nm0727778/', '6191091c06029e3acded09e4', '1', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWQzOWViN2ItNDZhOS00MmZlLTkxZTYtZDg5NGUwMGRmYWZjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWQzOWViN2ItNDZhOS00MmZlLTkxZTYtZDg5NGUwMGRmYWZjL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', 'The Mad King', ''),
#  ('Akho', '/character/ch0544520/', 'Chuku Modu', '/name/nm6729880/', '6191091c06029e3acded09e5', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGE4ZDZmOGUtNGE4Ny00Y2VmLThiOGItMjk3Y2U0ZDY3OWQxXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOGE4ZDZmOGUtNGE4Ny00Y2VmLThiOGItMjk3Y2U0ZDY3OWQxXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', '', ''),
#  ('Alliser Thorne', '/character/ch0246938/', 'Owen Teale', '/name/nm0853583/', '6191091c06029e3acded09e6', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAxMjExMjA3M15BMl5BanBnXkFtZTcwMjI1ODg5NA@@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAxMjExMjA3M15BMl5BanBnXkFtZTcwMjI1ODg5NA@@._V1_SY1000_CR0,0,666,1000_AL_.jpg', '', ''),
#  ('Alton Lannister', '/character/ch0305012/', 'Karl Davies', '/name/nm0203801/', '6191091c06029e3acded09e7', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU0NTU1NTAzOF5BMl5BanBnXkFtZTcwNzA2NDk4OA@@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU0NTU1NTAzOF5BMl5BanBnXkFtZTcwNzA2NDk4OA@@._V1_.jpg', '', ''),
#  ('Alys Karstark', '/character/ch0576836/', 'Megan Parkinson', '/name/nm8257864/', '6191091c06029e3acded09e8', '', '', '', '', ''),
#  ('Amory Lorch', '/character/ch0305002/', 'Fintan McKeown', '/name/nm0571654/', '6191091c06029e3acded09e9', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTVmY2M2YmUtY2JkYS00NjIyLWFhYTAtNTNlZmI4ODdiNmE5XkEyXkFqcGdeQXVyMjg2MTMyNTM@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BOTVmY2M2YmUtY2JkYS00NjIyLWFhYTAtNTNlZmI4ODdiNmE5XkEyXkFqcGdeQXVyMjg2MTMyNTM@._V1_.jpg', '', ''),
#  ('Anguy', '/character/ch0316930/', 'Philip McGinley', '/name/nm1528121/', '6191091c06029e3acded09ea', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNmRhY2M4YmItNjc2Yi00ZDc0LWE5NmUtNGE5OWE0YTQ2YjY3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNmRhY2M4YmItNjc2Yi00ZDc0LWE5NmUtNGE5OWE0YTQ2YjY3XkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', '', '')]

# %%
# %sql describe aa_S22_W4111_HW1.characters;
# Out:
#  * mysql+pymysql://root:***@localhost
# 10 rows affected.
# [('characterName', 'text', 'YES', '', None, ''),
#  ('characterLink', 'text', 'YES', '', None, ''),
#  ('actorName', 'text', 'YES', '', None, ''),
#  ('actorLink', 'text', 'YES', '', None, ''),
#  ('id', 'text', 'YES', '', None, ''),
#  ('royal', 'text', 'YES', '', None, ''),
#  ('characterImageThumb', 'text', 'YES', '', None, ''),
#  ('characterImageFull', 'text', 'YES', '', None, ''),
#  ('nickname', 'text', 'YES', '', None, ''),
#  ('kingsguard', 'text', 'YES', '', None, '')]

# %%
# %%sql
#
# use aa_S22_W4111_HW1;
#
# alter table characters modify royal varchar(1) null;
#
# alter table characters modify id varchar(24) null;
#
# alter table characters modify kingsguard varchar(1) null;
#
# #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 389 rows affected.
# 389 rows affected.
# 389 rows affected.
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'ON' at line 2")
# [SQL: #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %sql describe aa_S22_W4111_HW1.characters;
# Out:
#  * mysql+pymysql://root:***@localhost
# 10 rows affected.
# [('characterName', 'text', 'YES', '', None, ''),
#  ('characterLink', 'text', 'YES', '', None, ''),
#  ('actorName', 'text', 'YES', '', None, ''),
#  ('actorLink', 'text', 'YES', '', None, ''),
#  ('id', 'varchar(24)', 'YES', '', None, ''),
#  ('royal', 'varchar(1)', 'YES', '', None, ''),
#  ('characterImageThumb', 'text', 'YES', '', None, ''),
#  ('characterImageFull', 'text', 'YES', '', None, ''),
#  ('nickname', 'text', 'YES', '', None, ''),
#  ('kingsguard', 'varchar(1)', 'YES', '', None, '')]

# %% [markdown]
# ## Episodes
#
# - Perform the tasks for episodes.

# %%
# Create the schema if it does not exist.
# %sql create schema if not exists aa_S22_W4111_HW1;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-254-6cbb95b49b85> in <module>
#       1 # Create the schema if it does not exist.
# ----> 2 get_ipython().run_line_magic('sql', 'create schema if not exists aa_S22_W4111_HW1;')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# Drop the table if it exists.
# %sql drop table if exists aa_S22_W4111_HW1.episodes;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-256-5d01c7d594c4> in <module>
#       1 # Drop the table if it exists.
# ----> 2 get_ipython().run_line_magic('sql', 'drop table if exists aa_S22_W4111_HW1.episodes;')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# create table if not exists aa_S22_W4111_HW1.episodes
# (
# 	seasonNum text null,
# 	episodeNum text null,
# 	sceneNum text null,
# 	sceneLocation text null,
# 	sceneSubLocation text null,
# 	sceneStartTime text null,
#     sceneEndTime text null
# );
#
# #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'ON' at line 2")
# [SQL: #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# This command allows loading CSV files from the local disk.
# This is set of OFF by default.
# You should only have to run this once, that is if you execute the example, you do not need to do again.
#
# %sql SET GLOBAL local_infile = 'ON';
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-236-3dae89daab24> in <module>
#       3 # You should only have to run this once, that is if you execute the example, you do not need to do again.
#       4 #
# ----> 5 get_ipython().run_line_magic('sql', "SET GLOBAL local_infile = 'ON';")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# This is creating a connection to the database.
# You need to replace the user and passsword with your values for your installation of MySQL.
# Do not ask about the local_infile. That is Voldemort stuff.
#
con = pymysql.connect(host="localhost",
                        user="root",
                        password="Iriswonder@5216",
                        autocommit=True,
                        local_infile=1)

# %%
# This statement performs the load.
# You will need to change the TABLE name and the INFILE to the correct values.
#
sql = """
LOAD DATA LOCAL INFILE
'/Users/yanxichen/Desktop/DatabaseHW/S22-W4111-HW-1-0/data/GoT/episodes.csv'
INTO TABLE aa_S22_W4111_HW1.episodes
    FIELDS TERMINATED BY ','
    ENCLOSED BY '"'
    LINES TERMINATED BY '\n'
    IGNORE 1 LINES;
"""

# %%
# Create a cursor. Again. Voldemort stuff, or maybe Sauron stuff.
#
cur = con.cursor()

# %%
# Run the sql
cur.execute(sql)
# Out:
# 4165

# %%
# Close the cursor. Sort of like the opposite of alohomora
cur.close()

# %%
# Now test that your loading worked.
# %sql select * from aa_S22_W4111_HW1.episodes limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost
# 10 rows affected.
# [('1', '1', '0', 'The Wall', 'Castle Black', '0:00:40', '0:01:45'),
#  ('1', '1', '1', 'North of the Wall', 'The Haunted Forest', '0:01:45', '0:03:24'),
#  ('1', '1', '2', 'North of the Wall', 'The Haunted Forest', '0:03:24', '0:03:31'),
#  ('1', '1', '3', 'North of the Wall', 'The Haunted Forest', '0:03:31', '0:03:38'),
#  ('1', '1', '4', 'North of the Wall', 'The Haunted Forest', '0:03:38', '0:03:44'),
#  ('1', '1', '5', 'North of the Wall', 'The Haunted Forest', '0:03:44', '0:05:36'),
#  ('1', '1', '6', 'North of the Wall', 'The Haunted Forest', '0:05:36', '0:05:41'),
#  ('1', '1', '7', 'North of the Wall', 'The Haunted Forest', '0:05:41', '0:05:48'),
#  ('1', '1', '8', 'North of the Wall', 'The Haunted Forest', '0:05:48', '0:05:58'),
#  ('1', '1', '9', 'North of the Wall', 'The Haunted Forest', '0:05:58', '0:06:21')]

# %%
# %sql describe aa_S22_W4111_HW1.episodes;
# Out:
#  * mysql+pymysql://root:***@localhost
# 7 rows affected.
# [('seasonNum', 'text', 'YES', '', None, ''),
#  ('episodeNum', 'text', 'YES', '', None, ''),
#  ('sceneNum', 'text', 'YES', '', None, ''),
#  ('sceneLocation', 'text', 'YES', '', None, ''),
#  ('sceneSubLocation', 'text', 'YES', '', None, ''),
#  ('sceneStartTime', 'text', 'YES', '', None, ''),
#  ('sceneEndTime', 'text', 'YES', '', None, '')]

# %%
# %%sql
#
# use aa_S22_W4111_HW1;
#
# alter table episodes modify seasonNum varchar(1) null;
#
# alter table episodes modify episodeNum varchar(2) null;
#
# alter table episodes modify sceneNum varchar(3) null;
#
# alter table episodes modify sceneStartTime char(7) null;
#
# alter table episodes modify sceneEndTime char(7) null;
#
# #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 4165 rows affected.
# 4165 rows affected.
# 4165 rows affected.
# 4165 rows affected.
# 4165 rows affected.
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'ON' at line 2")
# [SQL: #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %sql describe aa_S22_W4111_HW1.episodes;
# Out:
#  * mysql+pymysql://root:***@localhost
# 7 rows affected.
# [('seasonNum', 'varchar(1)', 'YES', '', None, ''),
#  ('episodeNum', 'varchar(2)', 'YES', '', None, ''),
#  ('sceneNum', 'varchar(3)', 'YES', '', None, ''),
#  ('sceneLocation', 'text', 'YES', '', None, ''),
#  ('sceneSubLocation', 'text', 'YES', '', None, ''),
#  ('sceneStartTime', 'char(7)', 'YES', '', None, ''),
#  ('sceneEndTime', 'char(7)', 'YES', '', None, '')]

# %% [markdown]
# ## Characters Relationships
#
# - Perform the tasks for character_relationships.

# %%
# Create the schema if it does not exist.
# %sql create schema if not exists aa_S22_W4111_HW1;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-246-6cbb95b49b85> in <module>
#       1 # Create the schema if it does not exist.
# ----> 2 get_ipython().run_line_magic('sql', 'create schema if not exists aa_S22_W4111_HW1;')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# Drop the table if it exists.
# %sql drop table if exists aa_S22_W4111_HW1.character_relationships;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-247-d69ce9186814> in <module>
#       1 # Drop the table if it exists.
# ----> 2 get_ipython().run_line_magic('sql', 'drop table if exists aa_S22_W4111_HW1.character_relationships;')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# %%sql
# create table if not exists aa_S22_W4111_HW1.character_relationships
# (
# 	source_character_id text null,
# 	sourceCharacterName text null,
# 	relationship text null,
# 	target_character_id text null,
# 	targetCharacterName text null
# );
#
# #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'ON' at line 2")
# [SQL: #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# This command allows loading CSV files from the local disk.
# This is set of OFF by default.
# You should only have to run this once, that is if you execute the example, you do not need to do again.
#
# %sql SET GLOBAL local_infile = 'ON';
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-249-3dae89daab24> in <module>
#       3 # You should only have to run this once, that is if you execute the example, you do not need to do again.
#       4 #
# ----> 5 get_ipython().run_line_magic('sql', "SET GLOBAL local_infile = 'ON';")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2342                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2343             with self.builtin_trap:
# -> 2344                 result = fn(*args, **kwargs)
#    2345             return result
#    2346
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     342             if result and config.feedback:
#     343                 print(interpret_rowcount(result.rowcount))
# --> 344         resultset = ResultSet(result, statement, config)
#     345         if config.autopandas:
#     346             return resultset.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sql/run.py in __init__(self, sqlaproxy, sql, config)
#     105
#     106     def __init__(self, sqlaproxy, sql, config):
# --> 107         self.keys = sqlaproxy.keys()
#     108         self.sql = sql
#     109         self.config = config
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/result.py in keys(self)
#     705
#     706         """
# --> 707         return self._metadata.keys
#     708
#     709
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in keys(self)
#    1199     @property
#    1200     def keys(self):
# -> 1201         self._we_dont_return_rows()
#    1202
#    1203
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/cursor.py in _we_dont_return_rows(self, err)
#    1176
#    1177     def _we_dont_return_rows(self, err=None):
# -> 1178         util.raise_(
#    1179             exc.ResourceClosedError(
#    1180                 "This result object does not return rows. "
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
# This is creating a connection to the database.
# You need to replace the user and passsword with your values for your installation of MySQL.
# Do not ask about the local_infile. That is Voldemort stuff.
#
con = pymysql.connect(host="localhost",
                        user="root",
                        password="Iriswonder@5216",
                        autocommit=True,
                        local_infile=1)

# %%
# This statement performs the load.
# You will need to change the TABLE name and the INFILE to the correct values.
#
sql = """
LOAD DATA LOCAL INFILE
'/Users/yanxichen/Desktop/DatabaseHW/S22-W4111-HW-1-0/data/GoT/character_relationships.csv'
INTO TABLE aa_S22_W4111_HW1.character_relationships
    FIELDS TERMINATED BY ','
    ENCLOSED BY '"'
    LINES TERMINATED BY '\n'
    IGNORE 1 LINES;
"""

# %%
# Create a cursor. Again. Voldemort stuff, or maybe Sauron stuff.
#
cur = con.cursor()

# %%
# Run the sql
cur.execute(sql)
# Out:
# 785

# %%
# Close the cursor. Sort of like the opposite of alohomora
cur.close()

# %%
# Now test that your loading worked.
# %sql select * from aa_S22_W4111_HW1.character_relationships limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost
# 10 rows affected.
# [('6191091c06029e3acded09e2', 'Aegon Targaryen', 'parents', '6191091c06029e3acded0a20', 'Elia Martell'),
#  ('6191091c06029e3acded09e2', 'Aegon Targaryen', 'killedBy', '6191091c06029e3acded0a38', 'Gregor Clegane'),
#  ('6191091c06029e3acded09e2', 'Aegon Targaryen', 'siblings', '6191091c06029e3acded0a5c', 'Jon Snow'),
#  ('6191091c06029e3acded09e2', 'Aegon Targaryen', 'parents', '6191091c06029e3acded0af8', 'Rhaegar Targaryen'),
#  ('6191091c06029e3acded09e2', 'Aegon Targaryen', 'siblings', '6191091c06029e3acded0afb', 'Rhaenys Targaryen'),
#  ('6191091c06029e3acded09e3', 'Aeron Greyjoy', 'siblings', '6191091c06029e3acded09f2', 'Balon Greyjoy'),
#  ('6191091c06029e3acded09e3', 'Aeron Greyjoy', 'siblings', '6191091c06029e3acded0a22', 'Euron Greyjoy'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'servedBy', '6191091c06029e3acded09ef', 'Arthur Dayne'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'killed', '6191091c06029e3acded09fd', 'Brandon Stark'),
#  ('6191091c06029e3acded09e4', 'Aerys II Targaryen', 'parentOf', '6191091c06029e3acded0a0d', 'Daenerys Targaryen')]

# %%
# %sql describe aa_S22_W4111_HW1.character_relationships;
# Out:
#  * mysql+pymysql://root:***@localhost
# 5 rows affected.
# [('source_character_id', 'text', 'YES', '', None, ''),
#  ('sourceCharacterName', 'text', 'YES', '', None, ''),
#  ('relationship', 'text', 'YES', '', None, ''),
#  ('target_character_id', 'text', 'YES', '', None, ''),
#  ('targetCharacterName', 'text', 'YES', '', None, '')]

# %%
# %%sql
#
# use aa_S22_W4111_HW1;
#
# alter table character_relationships modify source_character_id varchar(24) null;
#
# alter table character_relationships modify target_character_id varchar(24) null;
#
# #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'ON' at line 2")
# [SQL: #This line below helps remove the ResourceClosedError
# SET NOCOUNT ON;]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %sql describe aa_S22_W4111_HW1.character_relationships;
# Out:
#  * mysql+pymysql://root:***@localhost
# 5 rows affected.
# [('source_character_id', 'varchar(24)', 'YES', '', None, ''),
#  ('sourceCharacterName', 'text', 'YES', '', None, ''),
#  ('relationship', 'text', 'YES', '', None, ''),
#  ('target_character_id', 'varchar(24)', 'YES', '', None, ''),
#  ('targetCharacterName', 'text', 'YES', '', None, '')]

# %%
# !ls -l ../../data/GoT
# Out:
# total 824
# -rw-r--r--@ 1 yanxichen  staff   67037 Feb  9 17:28 character_relationships.csv
# -rw-r--r--@ 1 yanxichen  staff  105989 Feb  9 17:28 characters.csv
# -rw-r--r--@ 1 yanxichen  staff  199361 Feb  9 17:28 episodes.csv
# -rw-r--r--  1 yanxichen  staff    9933 Feb  9 17:28 got_actors.csv
# -rw-r--r--  1 yanxichen  staff   29289 Feb  9 17:28 got_imdb_actors.csv

# %% [markdown]
# # Programming Track

# %% [markdown]
# Note: If you have activated [student license](https://www.jetbrains.com/community/education/#students) when installing Datagrip, you can also use Pycharm [Professional version](https://www.jetbrains.com/pycharm/download/#section=mac) instead of Community edition.

# %% [markdown]
# ## Tasks
#
# - You will create and modify files in the directory ```<uni>_web_src.```
#
#
# - You will use the database that comes with the book, e.g. ```db_book,``` that you previously installed.
#
#
# - Your web application will support ```GET``` on the path ```/api/db_book/students/<ID>.``` This means you have to implement two things:
#     1. A function in ```application.py``` that implements the path endpoint.
#     2. A method on a class ```Student``` that connects to the database, runs the SQL and returns the result. The project has been updated to have implementation templates for where your code goes.
#
#
# - For submission, you must copy your code from the Python file below to show your code.
#
#
# - You must include a screenshot of calling your application from a browser.

# %% [markdown]
# ## Modified application.py

# %% [markdown]
# ```
# from flask import Flask, Response, request
# import json
# from datetime import datetime
# import rest_utils
#
# app = Flask(__name__)
#
#
# ##################################################################################################################
#
# # DFF TODO A real service would have more robust health check methods.
# # This path simply echoes to check that the app is working.
# # The path is /health and the only method is GETs
# @app.route("/health", methods=["GET"])
# def health_check():
#     rsp_data = {"status": "healthy", "time": str(datetime.now())}
#     rsp_str = json.dumps(rsp_data)
#     rsp = Response(rsp_str, status=200, content_type="application/json")
#     return rsp
#
#
# # TODO Remove later. Solely for explanatory purposes.
# # The method take any REST request, and produces a response indicating what
# # the parameters, headers, etc. are. This is simply for education purposes.
# #
# @app.route("/api/demo/<parameter1>", methods=["GET", "POST", "PUT", "DELETE"])
# @app.route("/api/demo/", methods=["GET", "POST", "PUT", "DELETE"])
# def demo(parameter1=None):
#     """
#     Returns a JSON object containing a description of the received request.
#
#     :param parameter1: The first path parameter.
#     :return: JSON document containing information about the request.
#     """
#
#     # DFF TODO -- We should wrap with an exception pattern.
#     #
#
#     # Mostly for isolation. The rest of the method is isolated from the specifics of Flask.
#     inputs = rest_utils.RESTContext(request, {"parameter1": parameter1})
#
#     # DFF TODO -- We should replace with logging.
#     r_json = inputs.to_json()
#     msg = {
#         "/demo received the following inputs": inputs.to_json()
#     }
#     print("/api/demo/<parameter> received/returned:\n", msg)
#
#     rsp = Response(json.dumps(msg), status=200, content_type="application/json")
#     return rsp
#
# ##################################################################################################################
#
#
# @app.route("/api/db_book/students/<ID>", methods=["GET"])
# def get_student_by_id(ID):
#     #
#     # Your code goes here.
#     #
#     pass
#
#
# if __name__ == '__main__':
#     app.run(host="0.0.0.0", port=5000)
#
# ```

# %% [markdown]
# ## Modified student_resource.py

# %% [markdown]
# ```
#
# class Student:
#
#     def __init__(self):
#         # You may have to put code here.
#         pass
#
#     def get_by_id(self, ID):
#         # Connect to DB.
#         # Form SQL
#         # Run query
#         # return result
#         pass
# ```

# %% [markdown]
# ## Screen Capture of Calling from Browser
